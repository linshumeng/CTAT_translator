# %%
import pandas as pd
import re
import translators.server as tss
TARGET_LANG = 'es'

# %%
# read the latest mass production table
# path_new =  r".\Output_cleaned_folder\6_5_cleaned.txt"
path_new = r".\Output_cleaned_folder\7-17_finalMassProduction_new_cleaned.txt"
table_new = pd.read_csv(path_new, sep="\t", index_col=0, keep_default_na=False)

# %%
# Change column name
table_new_col_list = []
for i in table_new:
    if i.isdigit():
        table_new_col_list.append('Problem'+i)
    else:
        table_new_col_list.append(i)
table_new.columns = table_new_col_list   
# table_new.columns
# drop 'IntroProblem'
if 'IntroProblem' in table_new.columns:
    table_new = table_new.drop(['IntroProblem'], axis=1)
    print("drop IntroProblem")
table_new.head()
# Out:
#                                                                  Problem1  \
# Problem Name
# %(startStateNodeName)%                                            state56
# %(ProblemStatement)%    As part of their Get Fit campaign, the city of...
# %(Part)%                                                            16590
# %(Part-Hint1)%          What is the number of people who took part in ...
# %(Alex-ex-hint)%
#
#                                                                  Problem2  \
# Problem Name
# %(startStateNodeName)%                                            state27
# %(ProblemStatement)%    Timothy is flying from Los Angeles to New York...
# %(Part)%                                                              775
# %(Part-Hint1)%                How many miles has Timothy already covered?
# %(Alex-ex-hint)%
#
#                                                                  Problem3  \
# Problem Name
# %(startStateNodeName)%                                             state2
# %(ProblemStatement)%    Ed is installing carpeting in his house. He ha...
# %(Part)%                                                              243
# %(Part-Hint1)%          How much carpeting has Ed already installed in...
# %(Alex-ex-hint)%
#
#                                                                  Problem5  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Albert is reading a book that is 200 pages lon...
# %(Part)%                                                               72
# %(Part-Hint1)%          How many pages did Albert already read from th...
# %(Alex-ex-hint)%
#
#                                                                  Problem6  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    A radio program that consists of 3 fictional s...
# %(Part)%                                                               15
# %(Part-Hint1)%                           What is the length of one story?
# %(Alex-ex-hint)%
#
#                                                                  Problem7  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Jane is returning a poorly developed photograp...
# %(Part)%                                                             0.12
# %(Part-Hint1)%               How much credit did the shop return to Jane?
# %(Alex-ex-hint)%
#
#                                                                  Problem8  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    A political science student at a city universi...
# %(Part)%                                                               36
# %(Part-Hint1)%           How many people answered the question correctly?
# %(Alex-ex-hint)%
#
#                                                                  Problem9  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    One local newscast tries to lure viewers with ...
# %(Part)%                                                             1625
# %(Part-Hint1)%          How many viewers have won the contest in the l...
# %(Alex-ex-hint)%
#
#                                                                 Problem10  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    At the 2002 Winter Olympic Games in Salt Lake ...
# %(Part)%                                                               10
# %(Part-Hint1)%          How many athletes from team USA won gold medal...
# %(Alex-ex-hint)%
#
#                                                                 Problem11  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    A college undergraduate works in a coffee shop...
# %(Part)%                                                                2
# %(Part-Hint1)%          How much time does the student spend doing dis...
# %(Alex-ex-hint)%
#
#                         ...  \
# Problem Name            ...
# %(startStateNodeName)%  ...
# %(ProblemStatement)%    ...
# %(Part)%                ...
# %(Part-Hint1)%          ...
# %(Alex-ex-hint)%        ...
#
#                                                                 Problem15  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Joan is shocked when she received her very fir...
# %(Part)%                                                              710
# %(Part-Hint1)%                   How much of Joan's salary went to taxes?
# %(Alex-ex-hint)%
#
#                                                                 Problem16  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    A president's approval rating is determined by...
# %(Part)%                                                          1300000
# %(Part-Hint1)%          How many citizens approved of the president's ...
# %(Alex-ex-hint)%
#
#                                                                 Problem17  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    An encouraging survey by a local health organi...
# %(Part)%                                                             1980
# %(Part-Hint1)%          How many adults regularly participated in phys...
# %(Alex-ex-hint)%
#
#                                                                 Problem18  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    The cafeteria staff of your school thinks it h...
# %(Part)%                                                               10
# %(Part-Hint1)%                  How many students tried the healthy meal?
# %(Alex-ex-hint)%
#
#                                                                 Problem19  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Lisa is purchasing a pair of jeans from the cl...
# %(Part)%                                                            48.45
# %(Part-Hint1)%              How much did Lisa spend on the pair of jeans?
# %(Alex-ex-hint)%
#
#                                                                 Problem20  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    You decide to buy a new computer on one of the...
# %(Part)%                                                              105
# %(Part-Hint1)%                   How much did you save by not paying tax?
# %(Alex-ex-hint)%
#
#                                                                 Problem21  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Julie just took a job as a telemarketer, selli...
# %(Part)%                                                              189
# %(Part-Hint1)%          How many customers agreed to buy the company's...
# %(Alex-ex-hint)%
#
#                                                                 Problem22  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Chelsea completed 240 math problems in a compe...
# %(Part)%                                                               30
# %(Part-Hint1)%          How many geometry problems were there in the m...
# %(Alex-ex-hint)%
#
#                                                                 Problem23  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Alex practiced his driving regularly in the we...
# %(Part)%                                                              168
# %(Part-Hint1)%                                What was Alex's test score?
# %(Alex-ex-hint)%        If 7 points are deducted from the 175 possible...
#
#                                                                 Problem24
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    A dinner costs $35.00, and the waiter receives...
# %(Part)%                                                             5.25
# %(Part-Hint1)%                       How much tip did the waiter receive?
# %(Alex-ex-hint)%
#
# [5 rows x 23 columns]

# %%
# replace variable with value in the latest mass production table
# iterate column and row in table_new
for column in range(table_new.shape[1]):
    for row in range(table_new.shape[0]):
        content_new = str(table_new.iloc[row, column])
        start_pattern = "%\("
        # count the number of the replacement in one variable(content_new)
        count = [match.start() for match in re.finditer(start_pattern, str(content_new))]
        for i in range(len(count)):
            # find the variable
            start_pattern = "%\("
            start_index = [match.start() for match in re.finditer(start_pattern, str(content_new))]
            end_pattern = "\)%"
            end_index = [match.start() for match in re.finditer(end_pattern, str(content_new))]
            # no need for replacement
            if start_index == []:
                continue
            else:
                variable = content_new[start_index[0]: end_index[0]+2]
                # find the corresponding column name, and then find the value
                column_name = table_new.columns[column]
                try:
                    value = table_new.loc[variable, column_name] 
                    # print(variable, value)
                    content_new = content_new.replace(variable, value)
                    table_new.iloc[row, column] = content_new
                except:
                    print(variable + " doesn't exist")
table_new.head()
# Out:
#                                                                  Problem1  \
# Problem Name
# %(startStateNodeName)%                                            state56
# %(ProblemStatement)%    As part of their Get Fit campaign, the city of...
# %(Part)%                                                            16590
# %(Part-Hint1)%          What is the number of people who took part in ...
# %(Alex-ex-hint)%
#
#                                                                  Problem2  \
# Problem Name
# %(startStateNodeName)%                                            state27
# %(ProblemStatement)%    Timothy is flying from Los Angeles to New York...
# %(Part)%                                                              775
# %(Part-Hint1)%                How many miles has Timothy already covered?
# %(Alex-ex-hint)%
#
#                                                                  Problem3  \
# Problem Name
# %(startStateNodeName)%                                             state2
# %(ProblemStatement)%    Ed is installing carpeting in his house. He ha...
# %(Part)%                                                              243
# %(Part-Hint1)%          How much carpeting has Ed already installed in...
# %(Alex-ex-hint)%
#
#                                                                  Problem5  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Albert is reading a book that is 200 pages lon...
# %(Part)%                                                               72
# %(Part-Hint1)%          How many pages did Albert already read from th...
# %(Alex-ex-hint)%
#
#                                                                  Problem6  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    A radio program that consists of 3 fictional s...
# %(Part)%                                                               15
# %(Part-Hint1)%                           What is the length of one story?
# %(Alex-ex-hint)%
#
#                                                                  Problem7  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Jane is returning a poorly developed photograp...
# %(Part)%                                                             0.12
# %(Part-Hint1)%               How much credit did the shop return to Jane?
# %(Alex-ex-hint)%
#
#                                                                  Problem8  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    A political science student at a city universi...
# %(Part)%                                                               36
# %(Part-Hint1)%           How many people answered the question correctly?
# %(Alex-ex-hint)%
#
#                                                                  Problem9  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    One local newscast tries to lure viewers with ...
# %(Part)%                                                             1625
# %(Part-Hint1)%          How many viewers have won the contest in the l...
# %(Alex-ex-hint)%
#
#                                                                 Problem10  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    At the 2002 Winter Olympic Games in Salt Lake ...
# %(Part)%                                                               10
# %(Part-Hint1)%          How many athletes from team USA won gold medal...
# %(Alex-ex-hint)%
#
#                                                                 Problem11  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    A college undergraduate works in a coffee shop...
# %(Part)%                                                                2
# %(Part-Hint1)%          How much time does the student spend doing dis...
# %(Alex-ex-hint)%
#
#                         ...  \
# Problem Name            ...
# %(startStateNodeName)%  ...
# %(ProblemStatement)%    ...
# %(Part)%                ...
# %(Part-Hint1)%          ...
# %(Alex-ex-hint)%        ...
#
#                                                                 Problem15  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Joan is shocked when she received her very fir...
# %(Part)%                                                              710
# %(Part-Hint1)%                   How much of Joan's salary went to taxes?
# %(Alex-ex-hint)%
#
#                                                                 Problem16  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    A president's approval rating is determined by...
# %(Part)%                                                          1300000
# %(Part-Hint1)%          How many citizens approved of the president's ...
# %(Alex-ex-hint)%
#
#                                                                 Problem17  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    An encouraging survey by a local health organi...
# %(Part)%                                                             1980
# %(Part-Hint1)%          How many adults regularly participated in phys...
# %(Alex-ex-hint)%
#
#                                                                 Problem18  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    The cafeteria staff of your school thinks it h...
# %(Part)%                                                               10
# %(Part-Hint1)%                  How many students tried the healthy meal?
# %(Alex-ex-hint)%
#
#                                                                 Problem19  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Lisa is purchasing a pair of jeans from the cl...
# %(Part)%                                                            48.45
# %(Part-Hint1)%              How much did Lisa spend on the pair of jeans?
# %(Alex-ex-hint)%
#
#                                                                 Problem20  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    You decide to buy a new computer on one of the...
# %(Part)%                                                              105
# %(Part-Hint1)%                   How much did you save by not paying tax?
# %(Alex-ex-hint)%
#
#                                                                 Problem21  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Julie just took a job as a telemarketer, selli...
# %(Part)%                                                              189
# %(Part-Hint1)%          How many customers agreed to buy the company's...
# %(Alex-ex-hint)%
#
#                                                                 Problem22  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Chelsea completed 240 math problems in a compe...
# %(Part)%                                                               30
# %(Part-Hint1)%          How many geometry problems were there in the m...
# %(Alex-ex-hint)%
#
#                                                                 Problem23  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Alex practiced his driving regularly in the we...
# %(Part)%                                                              168
# %(Part-Hint1)%                                What was Alex's test score?
# %(Alex-ex-hint)%        If 7 points are deducted from the 175 possible...
#
#                                                                 Problem24
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    A dinner costs $35.00, and the waiter receives...
# %(Part)%                                                             5.25
# %(Part-Hint1)%                       How much tip did the waiter receive?
# %(Alex-ex-hint)%
#
# [5 rows x 23 columns]

# %%
# read the Greg's mass production table
# path_old = './Greg_table_folder/6.05 - Sheet1.csv'
path_old = './Greg_table_folder/7.17 - Sheet1.csv'
table_old = pd.read_csv(path_old, header = None)
# table_old.head()
# skip some rows, because they are translation for HTML elements
header_index = table_old.index[table_old[0] == 'Problem Name'].to_list()
header_index
# reload the csv
table_old = pd.read_csv(path_old, header = header_index)
table_old.columns
# Out:
# Index(['Problem Name', 'Problem1', 'Problem1ESP', 'Problem Name.1', 'Problem2',
#        'Problem2ESP', 'Problem Name.2', 'Problem3', 'Problem3ESP',
#        'Problem Name.3', 'Problem4', 'Problem4ESP', 'Problem Name.4',
#        'Problem5', 'Problem5ESP', 'Problem Name.5', 'Problem6', 'Problem6ESP',
#        'Problem Name.6', 'Problem7', 'Problem7ESP', 'Problem Name.7',
#        'Problem8', 'Problem8ESP', 'Problem Name.8', 'Problem9', 'Problem9ESP',
#        'Problem Name.9', 'Problem10', 'Problem10ESP', 'Problem Name.10',
#        'Problem11', 'Problem11ESP', 'Problem Name.11', 'Problem12',
#        'Problem12ESP', 'Problem Name.12', 'Problem13', 'Problem13ESP',
#        'Problem Name.13', 'Problem14', 'Problem14ESP', 'Problem Name.14',
#        'Problem15', 'Problem15ESP', 'Problem Name.15', 'Problem16',
#        'Problem16ESP', 'Problem Name.16', 'Problem17', 'Problem17ESP',
#        'Problem Name.17', 'Problem18', 'Problem18ESP', 'Problem Name.18',
#        'Problem19', 'Problem19ESP', 'Problem Name.19', 'Problem20',
#        'Problem20ESP', 'Problem Name.20', 'Problem21', 'Problem21ESP',
#        'Problem Name.21', 'Problem22', 'Problem22ESP', 'Problem Name.22',
#        'Problem23', 'Problem23ESP', 'Problem Name.23', 'Problem24',
#        'Problem24ESP', 'Problem Name.24', 'Problem25', 'Problem25ESP',
#        'Problem Name.25', 'Problem26', 'Problem26ESP'],
#       dtype='object')

# %%
# table_translated = pd.DataFrame(columns=table_old.columns, index=range(table_new.shape[0]))
# Create a new table, with the column from the Greg's mass production table and the index from the latest mass production table
table_translated = pd.DataFrame(columns=table_old.columns, index=table_new.index)
table_translated
# Out:
#                        Problem Name Problem1 Problem1ESP Problem Name.1  \
# Problem Name
# %(startStateNodeName)%          NaN      NaN         NaN            NaN
# %(ProblemStatement)%            NaN      NaN         NaN            NaN
# %(Part)%                        NaN      NaN         NaN            NaN
# %(Part-Hint1)%                  NaN      NaN         NaN            NaN
# %(Alex-ex-hint)%                NaN      NaN         NaN            NaN
# ...                             ...      ...         ...            ...
# %(Input_30_1)%                  NaN      NaN         NaN            NaN
# %(Input_49_1)%                  NaN      NaN         NaN            NaN
# %(Input_67_means)%              NaN      NaN         NaN            NaN
# %(Input_69_az)%                 NaN      NaN         NaN            NaN
# %(Input_73_fractions)%          NaN      NaN         NaN            NaN
#
#                        Problem2 Problem2ESP Problem Name.2 Problem3  \
# Problem Name
# %(startStateNodeName)%      NaN         NaN            NaN      NaN
# %(ProblemStatement)%        NaN         NaN            NaN      NaN
# %(Part)%                    NaN         NaN            NaN      NaN
# %(Part-Hint1)%              NaN         NaN            NaN      NaN
# %(Alex-ex-hint)%            NaN         NaN            NaN      NaN
# ...                         ...         ...            ...      ...
# %(Input_30_1)%              NaN         NaN            NaN      NaN
# %(Input_49_1)%              NaN         NaN            NaN      NaN
# %(Input_67_means)%          NaN         NaN            NaN      NaN
# %(Input_69_az)%             NaN         NaN            NaN      NaN
# %(Input_73_fractions)%      NaN         NaN            NaN      NaN
#
#                        Problem3ESP Problem Name.3  ... Problem23ESP  \
# Problem Name                                       ...
# %(startStateNodeName)%         NaN            NaN  ...          NaN
# %(ProblemStatement)%           NaN            NaN  ...          NaN
# %(Part)%                       NaN            NaN  ...          NaN
# %(Part-Hint1)%                 NaN            NaN  ...          NaN
# %(Alex-ex-hint)%               NaN            NaN  ...          NaN
# ...                            ...            ...  ...          ...
# %(Input_30_1)%                 NaN            NaN  ...          NaN
# %(Input_49_1)%                 NaN            NaN  ...          NaN
# %(Input_67_means)%             NaN            NaN  ...          NaN
# %(Input_69_az)%                NaN            NaN  ...          NaN
# %(Input_73_fractions)%         NaN            NaN  ...          NaN
#
#                        Problem Name.23 Problem24 Problem24ESP Problem Name.24  \
# Problem Name
# %(startStateNodeName)%             NaN       NaN          NaN             NaN
# %(ProblemStatement)%               NaN       NaN          NaN             NaN
# %(Part)%                           NaN       NaN          NaN             NaN
# %(Part-Hint1)%                     NaN       NaN          NaN             NaN
# %(Alex-ex-hint)%                   NaN       NaN          NaN             NaN
# ...                                ...       ...          ...             ...
# %(Input_30_1)%                     NaN       NaN          NaN             NaN
# %(Input_49_1)%                     NaN       NaN          NaN             NaN
# %(Input_67_means)%                 NaN       NaN          NaN             NaN
# %(Input_69_az)%                    NaN       NaN          NaN             NaN
# %(Input_73_fractions)%             NaN       NaN          NaN             NaN
#
#                        Problem25 Problem25ESP Problem Name.25 Problem26  \
# Problem Name
# %(startStateNodeName)%       NaN          NaN             NaN       NaN
# %(ProblemStatement)%         NaN          NaN             NaN       NaN
# %(Part)%                     NaN          NaN             NaN       NaN
# %(Part-Hint1)%               NaN          NaN             NaN       NaN
# %(Alex-ex-hint)%             NaN          NaN             NaN       NaN
# ...                          ...          ...             ...       ...
# %(Input_30_1)%               NaN          NaN             NaN       NaN
# %(Input_49_1)%               NaN          NaN             NaN       NaN
# %(Input_67_means)%           NaN          NaN             NaN       NaN
# %(Input_69_az)%              NaN          NaN             NaN       NaN
# %(Input_73_fractions)%       NaN          NaN             NaN       NaN
#
#                        Problem26ESP
# Problem Name
# %(startStateNodeName)%          NaN
# %(ProblemStatement)%            NaN
# %(Part)%                        NaN
# %(Part-Hint1)%                  NaN
# %(Alex-ex-hint)%                NaN
# ...                             ...
# %(Input_30_1)%                  NaN
# %(Input_49_1)%                  NaN
# %(Input_67_means)%              NaN
# %(Input_69_az)%                 NaN
# %(Input_73_fractions)%          NaN
#
# [105 rows x 78 columns]

# %%
# find the translation of the latest mass production table from the Greg's mass production table 
google_dict = {}
for column in range(table_new.shape[1]):
    for row in range(table_new.shape[0]):
        content_new = str(table_new.iloc[row, column])
        column_name = table_new.columns[column]
        table_translated[column_name].iloc[row] = content_new
        column_num = table_translated.columns.get_loc(column_name)
        # no translation
        if table_old[table_old[column_name] == str(content_new)].empty:
            if content_new.isdigit() or content_new == '':
                print("digital or empty")
                content_translated = content_new
            elif content_new in google_dict:
                print("find translation in dict")
                content_translated = google_dict[content_new]
            else:
                print("use google translation")
                try:
                    translation = tss.google(content_new, from_language='en', to_language=TARGET_LANG)
                except:
                    translation = 'error'
                content_translated = '[google]' + translation
                google_dict[content_new] = content_translated
        # find translation
        else:
            print("find translation in sheet")
            content_translated = table_old[table_old[column_name] == str(content_new)].iloc[0,column_num+1]
        # # print(content_translated)
        table_translated.iloc[row, column_num+1] = content_translated
        # # content_translated
table_translated
# Out:
# use google translation
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# digital or empty
# use google translation
# use google translation
# use google translation
# find translation in dict
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# use google translation
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# use google translation
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in dict
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in dict
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# digital or empty
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# digital or empty
# use google translation
# use google translation
# find translation in sheet
# use google translation
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# digital or empty
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# digital or empty
# use google translation
# use google translation
# find translation in sheet
# use google translation
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# digital or empty
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# find translation in dict
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# use google translation
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# use google translation
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# digital or empty
# digital or empty
# digital or empty
# find translation in dict
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# use google translation
# use google translation
# find translation in sheet
# use google translation
# digital or empty
# digital or empty
# digital or empty
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in dict
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# digital or empty
# find translation in dict
# use google translation
# find translation in dict
# find translation in dict
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in dict
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# digital or empty
# find translation in dict
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# use google translation
# use google translation
# find translation in dict
# use google translation
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# digital or empty
# digital or empty
# find translation in dict
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# use google translation
# use google translation
# find translation in dict
# use google translation
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# use google translation
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# use google translation
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# find translation in dict
# use google translation
# find translation in dict
# find translation in dict
# digital or empty
# use google translation
# use google translation
# find translation in dict
# use google translation
# digital or empty
# digital or empty
# digital or empty
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in dict
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# digital or empty
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# digital or empty
# use google translation
# use google translation
# find translation in dict
# use google translation
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in dict
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# digital or empty
# find translation in dict
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# digital or empty
# find translation in dict
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# digital or empty
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# digital or empty
# use google translation
# use google translation
# find translation in dict
# use google translation
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# use google translation
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in dict
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# digital or empty
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# digital or empty
# use google translation
# use google translation
# find translation in dict
# use google translation
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in dict
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# digital or empty
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# digital or empty
# use google translation
# use google translation
# find translation in sheet
# use google translation
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# find translation in dict
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# use google translation
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# digital or empty
# digital or empty
# digital or empty
# find translation in dict
# use google translation
# find translation in dict
# find translation in dict
# digital or empty
# use google translation
# find translation in dict
# find translation in dict
# find translation in dict
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# use google translation
# digital or empty
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# digital or empty
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# digital or empty
# use google translation
# find translation in dict
# find translation in dict
# find translation in dict
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# digital or empty
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# ...
# use google translation
# use google translation
# use google translation
# digital or empty
# digital or empty
# use google translation
# use google translation
# use google translation
# use google translation
# use google translation
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# digital or empty
# use google translation
# digital or empty
# find translation in sheet
# find translation in sheet
# digital or empty
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# digital or empty
# use google translation
# find translation in dict
# find translation in dict
# find translation in dict
# digital or empty
# digital or empty
# find translation in sheet
# digital or empty
# digital or empty
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# use google translation
# use google translation
# find translation in dict
# find translation in sheet
# use google translation
# find translation in sheet
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in dict
# find translation in dict
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# use google translation
# find translation in dict
# find translation in dict
# use google translation
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
# find translation in sheet
#                        Problem Name  \
# Problem Name
# %(startStateNodeName)%          NaN
# %(ProblemStatement)%            NaN
# %(Part)%                        NaN
# %(Part-Hint1)%                  NaN
# %(Alex-ex-hint)%                NaN
# ...                             ...
# %(Input_30_1)%                  NaN
# %(Input_49_1)%                  NaN
# %(Input_67_means)%              NaN
# %(Input_69_az)%                 NaN
# %(Input_73_fractions)%          NaN
#
#                                                                  Problem1  \
# Problem Name
# %(startStateNodeName)%                                            state56
# %(ProblemStatement)%    As part of their Get Fit campaign, the city of...
# %(Part)%                                                            16590
# %(Part-Hint1)%          What is the number of people who took part in ...
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  means
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                          fractions
#
#                                                               Problem1ESP  \
# Problem Name
# %(startStateNodeName)%                                   [google]Estado56
# %(ProblemStatement)%    [google]Como parte de su campaña Get Fit, la c...
# %(Part)%                                                            16590
# %(Part-Hint1)%          [google]¿Cuál es el número de personas que par...
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
#                        Problem Name.1  \
# Problem Name
# %(startStateNodeName)%            NaN
# %(ProblemStatement)%              NaN
# %(Part)%                          NaN
# %(Part-Hint1)%                    NaN
# %(Alex-ex-hint)%                  NaN
# ...                               ...
# %(Input_30_1)%                    NaN
# %(Input_49_1)%                    NaN
# %(Input_67_means)%                NaN
# %(Input_69_az)%                   NaN
# %(Input_73_fractions)%            NaN
#
#                                                                  Problem2  \
# Problem Name
# %(startStateNodeName)%                                            state27
# %(ProblemStatement)%    Timothy is flying from Los Angeles to New York...
# %(Part)%                                                              775
# %(Part-Hint1)%                How many miles has Timothy already covered?
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  means
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                          fractions
#
#                                                               Problem2ESP  \
# Problem Name
# %(startStateNodeName)%                                   [google]Estado27
# %(ProblemStatement)%    [google]Timothy está volando de Los Ángeles a ...
# %(Part)%                                                              775
# %(Part-Hint1)%            [google]¿Cuántas millas ya ha cubierto Timothy?
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
#                        Problem Name.2  \
# Problem Name
# %(startStateNodeName)%            NaN
# %(ProblemStatement)%              NaN
# %(Part)%                          NaN
# %(Part-Hint1)%                    NaN
# %(Alex-ex-hint)%                  NaN
# ...                               ...
# %(Input_30_1)%                    NaN
# %(Input_49_1)%                    NaN
# %(Input_67_means)%                NaN
# %(Input_69_az)%                   NaN
# %(Input_73_fractions)%            NaN
#
#                                                                  Problem3  \
# Problem Name
# %(startStateNodeName)%                                             state2
# %(ProblemStatement)%    Ed is installing carpeting in his house. He ha...
# %(Part)%                                                              243
# %(Part-Hint1)%          How much carpeting has Ed already installed in...
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  means
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                          fractions
#
#                                                               Problem3ESP  \
# Problem Name
# %(startStateNodeName)%                                    [google]Estado2
# %(ProblemStatement)%    [google]Ed está instalando alfombras en su cas...
# %(Part)%                                                              243
# %(Part-Hint1)%          [google]¿Cuánta alfombra ya ha instalado Ed en...
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
#                        Problem Name.3  ...  \
# Problem Name                           ...
# %(startStateNodeName)%            NaN  ...
# %(ProblemStatement)%              NaN  ...
# %(Part)%                          NaN  ...
# %(Part-Hint1)%                    NaN  ...
# %(Alex-ex-hint)%                  NaN  ...
# ...                               ...  ...
# %(Input_30_1)%                    NaN  ...
# %(Input_49_1)%                    NaN  ...
# %(Input_67_means)%                NaN  ...
# %(Input_69_az)%                   NaN  ...
# %(Input_73_fractions)%            NaN  ...
#
#                                                              Problem23ESP  \
# Problem Name
# %(startStateNodeName)%                                  [google]Estado116
# %(ProblemStatement)%    [google]Alex practicó su conducción regularmen...
# %(Part)%                                                              168
# %(Part-Hint1)%            [google]¿Cuál fue el puntaje de prueba de Alex?
# %(Alex-ex-hint)%        [google]Si se deducen 7 puntos de los 175 punt...
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
#                        Problem Name.23  \
# Problem Name
# %(startStateNodeName)%             NaN
# %(ProblemStatement)%               NaN
# %(Part)%                           NaN
# %(Part-Hint1)%                     NaN
# %(Alex-ex-hint)%                   NaN
# ...                                ...
# %(Input_30_1)%                     NaN
# %(Input_49_1)%                     NaN
# %(Input_67_means)%                 NaN
# %(Input_69_az)%                    NaN
# %(Input_73_fractions)%             NaN
#
#                                                                 Problem24  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    A dinner costs $35.00, and the waiter receives...
# %(Part)%                                                             5.25
# %(Part-Hint1)%                       How much tip did the waiter receive?
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  means
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                          fractions
#
#                                                              Problem24ESP  \
# Problem Name
# %(startStateNodeName)%                                  [google]Estado116
# %(ProblemStatement)%    [google]Una cena cuesta $ 35.00, y el camarero...
# %(Part)%                                                     [google]5.25
# %(Part-Hint1)%               [google]¿Cuánto consejo recibió el camarero?
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
#                        Problem Name.24 Problem25 Problem25ESP Problem Name.25  \
# Problem Name
# %(startStateNodeName)%             NaN       NaN          NaN             NaN
# %(ProblemStatement)%               NaN       NaN          NaN             NaN
# %(Part)%                           NaN       NaN          NaN             NaN
# %(Part-Hint1)%                     NaN       NaN          NaN             NaN
# %(Alex-ex-hint)%                   NaN       NaN          NaN             NaN
# ...                                ...       ...          ...             ...
# %(Input_30_1)%                     NaN       NaN          NaN             NaN
# %(Input_49_1)%                     NaN       NaN          NaN             NaN
# %(Input_67_means)%                 NaN       NaN          NaN             NaN
# %(Input_69_az)%                    NaN       NaN          NaN             NaN
# %(Input_73_fractions)%             NaN       NaN          NaN             NaN
#
#                        Problem26 Problem26ESP
# Problem Name
# %(startStateNodeName)%       NaN          NaN
# %(ProblemStatement)%         NaN          NaN
# %(Part)%                     NaN          NaN
# %(Part-Hint1)%               NaN          NaN
# %(Alex-ex-hint)%             NaN          NaN
# ...                          ...          ...
# %(Input_30_1)%               NaN          NaN
# %(Input_49_1)%               NaN          NaN
# %(Input_67_means)%           NaN          NaN
# %(Input_69_az)%              NaN          NaN
# %(Input_73_fractions)%       NaN          NaN
#
# [105 rows x 78 columns]

# %%
table_translated.head()
# Out:
#                        Problem Name  \
# Problem Name
# %(startStateNodeName)%          NaN
# %(ProblemStatement)%            NaN
# %(Part)%                        NaN
# %(Part-Hint1)%                  NaN
# %(Alex-ex-hint)%                NaN
#
#                                                                  Problem1  \
# Problem Name
# %(startStateNodeName)%                                            state56
# %(ProblemStatement)%    As part of their Get Fit campaign, the city of...
# %(Part)%                                                            16590
# %(Part-Hint1)%          What is the number of people who took part in ...
# %(Alex-ex-hint)%
#
#                                                               Problem1ESP  \
# Problem Name
# %(startStateNodeName)%                                   [google]Estado56
# %(ProblemStatement)%    [google]Como parte de su campaña Get Fit, la c...
# %(Part)%                                                            16590
# %(Part-Hint1)%          [google]¿Cuál es el número de personas que par...
# %(Alex-ex-hint)%
#
#                        Problem Name.1  \
# Problem Name
# %(startStateNodeName)%            NaN
# %(ProblemStatement)%              NaN
# %(Part)%                          NaN
# %(Part-Hint1)%                    NaN
# %(Alex-ex-hint)%                  NaN
#
#                                                                  Problem2  \
# Problem Name
# %(startStateNodeName)%                                            state27
# %(ProblemStatement)%    Timothy is flying from Los Angeles to New York...
# %(Part)%                                                              775
# %(Part-Hint1)%                How many miles has Timothy already covered?
# %(Alex-ex-hint)%
#
#                                                               Problem2ESP  \
# Problem Name
# %(startStateNodeName)%                                   [google]Estado27
# %(ProblemStatement)%    [google]Timothy está volando de Los Ángeles a ...
# %(Part)%                                                              775
# %(Part-Hint1)%            [google]¿Cuántas millas ya ha cubierto Timothy?
# %(Alex-ex-hint)%
#
#                        Problem Name.2  \
# Problem Name
# %(startStateNodeName)%            NaN
# %(ProblemStatement)%              NaN
# %(Part)%                          NaN
# %(Part-Hint1)%                    NaN
# %(Alex-ex-hint)%                  NaN
#
#                                                                  Problem3  \
# Problem Name
# %(startStateNodeName)%                                             state2
# %(ProblemStatement)%    Ed is installing carpeting in his house. He ha...
# %(Part)%                                                              243
# %(Part-Hint1)%          How much carpeting has Ed already installed in...
# %(Alex-ex-hint)%
#
#                                                               Problem3ESP  \
# Problem Name
# %(startStateNodeName)%                                    [google]Estado2
# %(ProblemStatement)%    [google]Ed está instalando alfombras en su cas...
# %(Part)%                                                              243
# %(Part-Hint1)%          [google]¿Cuánta alfombra ya ha instalado Ed en...
# %(Alex-ex-hint)%
#
#                        Problem Name.3  ...  \
# Problem Name                           ...
# %(startStateNodeName)%            NaN  ...
# %(ProblemStatement)%              NaN  ...
# %(Part)%                          NaN  ...
# %(Part-Hint1)%                    NaN  ...
# %(Alex-ex-hint)%                  NaN  ...
#
#                                                              Problem23ESP  \
# Problem Name
# %(startStateNodeName)%                                  [google]Estado116
# %(ProblemStatement)%    [google]Alex practicó su conducción regularmen...
# %(Part)%                                                              168
# %(Part-Hint1)%            [google]¿Cuál fue el puntaje de prueba de Alex?
# %(Alex-ex-hint)%        [google]Si se deducen 7 puntos de los 175 punt...
#
#                        Problem Name.23  \
# Problem Name
# %(startStateNodeName)%             NaN
# %(ProblemStatement)%               NaN
# %(Part)%                           NaN
# %(Part-Hint1)%                     NaN
# %(Alex-ex-hint)%                   NaN
#
#                                                                 Problem24  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    A dinner costs $35.00, and the waiter receives...
# %(Part)%                                                             5.25
# %(Part-Hint1)%                       How much tip did the waiter receive?
# %(Alex-ex-hint)%
#
#                                                              Problem24ESP  \
# Problem Name
# %(startStateNodeName)%                                  [google]Estado116
# %(ProblemStatement)%    [google]Una cena cuesta $ 35.00, y el camarero...
# %(Part)%                                                     [google]5.25
# %(Part-Hint1)%               [google]¿Cuánto consejo recibió el camarero?
# %(Alex-ex-hint)%
#
#                        Problem Name.24 Problem25 Problem25ESP Problem Name.25  \
# Problem Name
# %(startStateNodeName)%             NaN       NaN          NaN             NaN
# %(ProblemStatement)%               NaN       NaN          NaN             NaN
# %(Part)%                           NaN       NaN          NaN             NaN
# %(Part-Hint1)%                     NaN       NaN          NaN             NaN
# %(Alex-ex-hint)%                   NaN       NaN          NaN             NaN
#
#                        Problem26 Problem26ESP
# Problem Name
# %(startStateNodeName)%       NaN          NaN
# %(ProblemStatement)%         NaN          NaN
# %(Part)%                     NaN          NaN
# %(Part-Hint1)%               NaN          NaN
# %(Alex-ex-hint)%             NaN          NaN
#
# [5 rows x 78 columns]

# %%
# drop NaN columns
table_translated_drop = table_translated.dropna(axis = 1, how = "all")
table_translated_drop
# Out:
#                                                                  Problem1  \
# Problem Name
# %(startStateNodeName)%                                            state56
# %(ProblemStatement)%    As part of their Get Fit campaign, the city of...
# %(Part)%                                                            16590
# %(Part-Hint1)%          What is the number of people who took part in ...
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  means
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                          fractions
#
#                                                               Problem1ESP  \
# Problem Name
# %(startStateNodeName)%                                   [google]Estado56
# %(ProblemStatement)%    [google]Como parte de su campaña Get Fit, la c...
# %(Part)%                                                            16590
# %(Part-Hint1)%          [google]¿Cuál es el número de personas que par...
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
#                                                                  Problem2  \
# Problem Name
# %(startStateNodeName)%                                            state27
# %(ProblemStatement)%    Timothy is flying from Los Angeles to New York...
# %(Part)%                                                              775
# %(Part-Hint1)%                How many miles has Timothy already covered?
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  means
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                          fractions
#
#                                                               Problem2ESP  \
# Problem Name
# %(startStateNodeName)%                                   [google]Estado27
# %(ProblemStatement)%    [google]Timothy está volando de Los Ángeles a ...
# %(Part)%                                                              775
# %(Part-Hint1)%            [google]¿Cuántas millas ya ha cubierto Timothy?
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
#                                                                  Problem3  \
# Problem Name
# %(startStateNodeName)%                                             state2
# %(ProblemStatement)%    Ed is installing carpeting in his house. He ha...
# %(Part)%                                                              243
# %(Part-Hint1)%          How much carpeting has Ed already installed in...
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  means
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                          fractions
#
#                                                               Problem3ESP  \
# Problem Name
# %(startStateNodeName)%                                    [google]Estado2
# %(ProblemStatement)%    [google]Ed está instalando alfombras en su cas...
# %(Part)%                                                              243
# %(Part-Hint1)%          [google]¿Cuánta alfombra ya ha instalado Ed en...
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
#                                                                  Problem5  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Albert is reading a book that is 200 pages lon...
# %(Part)%                                                               72
# %(Part-Hint1)%          How many pages did Albert already read from th...
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  means
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                          fractions
#
#                                                               Problem5ESP  \
# Problem Name
# %(startStateNodeName)%                                  [google]Estado116
# %(ProblemStatement)%    [google]Albert está leyendo un libro que tiene...
# %(Part)%                                                               72
# %(Part-Hint1)%          [google]¿Cuántas páginas ya leía Albert del li...
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
#                                                                  Problem6  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    A radio program that consists of 3 fictional s...
# %(Part)%                                                               15
# %(Part-Hint1)%                           What is the length of one story?
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  means
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                          fractions
#
#                                                               Problem6ESP  \
# Problem Name
# %(startStateNodeName)%                                  [google]Estado116
# %(ProblemStatement)%    [google]Un programa de radio que consta de 3 h...
# %(Part)%                                                               15
# %(Part-Hint1)%              [google]¿Cuál es la duración de una historia?
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                        NaN
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
#                         ...  \
# Problem Name            ...
# %(startStateNodeName)%  ...
# %(ProblemStatement)%    ...
# %(Part)%                ...
# %(Part-Hint1)%          ...
# %(Alex-ex-hint)%        ...
# ...                     ...
# %(Input_30_1)%          ...
# %(Input_49_1)%          ...
# %(Input_67_means)%      ...
# %(Input_69_az)%         ...
# %(Input_73_fractions)%  ...
#
#                                                                 Problem20  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    You decide to buy a new computer on one of the...
# %(Part)%                                                              105
# %(Part-Hint1)%                   How much did you save by not paying tax?
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  means
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                          fractions
#
#                                                              Problem20ESP  \
# Problem Name
# %(startStateNodeName)%                                  [google]Estado116
# %(ProblemStatement)%    [google]Usted decide comprar una nueva computa...
# %(Part)%                                                              105
# %(Part-Hint1)%              [google]¿Cuánto ahorró al no pagar impuestos?
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
#                                                                 Problem21  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Julie just took a job as a telemarketer, selli...
# %(Part)%                                                              189
# %(Part-Hint1)%          How many customers agreed to buy the company's...
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  means
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                          fractions
#
#                                                              Problem21ESP  \
# Problem Name
# %(startStateNodeName)%                                  [google]Estado116
# %(ProblemStatement)%    [google]¡Julie acaba de tomar un trabajo como ...
# %(Part)%                                                              189
# %(Part-Hint1)%          [google]¿Cuántos clientes acordaron comprar lo...
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
#                                                                 Problem22  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Chelsea completed 240 math problems in a compe...
# %(Part)%                                                               30
# %(Part-Hint1)%          How many geometry problems were there in the m...
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  means
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                          fractions
#
#                                                              Problem22ESP  \
# Problem Name
# %(startStateNodeName)%                                  [google]Estado116
# %(ProblemStatement)%    [google]Chelsea completó 240 problemas matemát...
# %(Part)%                                                               30
# %(Part-Hint1)%          [google]¿Cuántos problemas de geometría había ...
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
#                                                                 Problem23  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    Alex practiced his driving regularly in the we...
# %(Part)%                                                              168
# %(Part-Hint1)%                                What was Alex's test score?
# %(Alex-ex-hint)%        If 7 points are deducted from the 175 possible...
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  means
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                          fractions
#
#                                                              Problem23ESP  \
# Problem Name
# %(startStateNodeName)%                                  [google]Estado116
# %(ProblemStatement)%    [google]Alex practicó su conducción regularmen...
# %(Part)%                                                              168
# %(Part-Hint1)%            [google]¿Cuál fue el puntaje de prueba de Alex?
# %(Alex-ex-hint)%        [google]Si se deducen 7 puntos de los 175 punt...
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
#                                                                 Problem24  \
# Problem Name
# %(startStateNodeName)%                                           state116
# %(ProblemStatement)%    A dinner costs $35.00, and the waiter receives...
# %(Part)%                                                             5.25
# %(Part-Hint1)%                       How much tip did the waiter receive?
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  means
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                          fractions
#
#                                                              Problem24ESP
# Problem Name
# %(startStateNodeName)%                                  [google]Estado116
# %(ProblemStatement)%    [google]Una cena cuesta $ 35.00, y el camarero...
# %(Part)%                                                     [google]5.25
# %(Part-Hint1)%               [google]¿Cuánto consejo recibió el camarero?
# %(Alex-ex-hint)%
# ...                                                                   ...
# %(Input_30_1)%                                                         -1
# %(Input_49_1)%                                                          1
# %(Input_67_means)%                                                  media
# %(Input_69_az)%                                                     [A-Z]
# %(Input_73_fractions)%                                         fracciones
#
# [105 rows x 46 columns]

# %%
# table_translated_drop.loc["%(tar1)%"]

# %%
# export the csv
table_translated_drop = table_translated_drop.fillna("[CTAT]NAN")
# table_translated_drop.to_csv('./Output_translated_folder/6.5_translated.txt', encoding="utf-8", sep="\t")
table_translated_drop.to_csv('./Output_translated_folder/7.17_translated.txt', encoding="utf-8", sep="\t")
