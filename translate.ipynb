# %%
import pandas as pd
import re
import translators.server as tss
TARGET_LANG = 'es'

# %%
# read the latest mass production table
# path_new = "./HTML_folder//6.05 HTML/6.05 HTML/MassProduction/6_5.txt"
path_new =  r".\Output_cleaned_folder\6_5_cleaned.txt"
# path_new = r".\Output_cleaned_folder\7-17_finalMassProduction_new_cleaned.txt"
table_new = pd.read_csv(path_new, sep="\t", index_col=0, keep_default_na=False)

# %%
# Change column name
table_new_col_list = []
for i in table_new:
    if i.isdigit():
        table_new_col_list.append('Problem'+i)
    else:
        table_new_col_list.append(i)
table_new.columns = table_new_col_list   
# table_new.columns
# drop 'IntroProblem'
if 'IntroProblem' in table_new.columns:
    table_new = table_new.drop(['IntroProblem'], axis=1)
    print("drop IntroProblem")
table_new.head()
# Out:
#                                                                  Problem1  \
# Problem Name
# %(startStateNodeName)%                                           example1
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/01.png
# %(question1)%               (1) What percent of the shapes are %(type1)%?
# %(question2)%               (2) What percent of the shapes are %(type2)%?
#
#                                                                  Problem2  \
# Problem Name
# %(startStateNodeName)%                                           example2
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/02.png
# %(question1)%               (1) What percent of the shapes are %(type1)%?
# %(question2)%               (2) What percent of the shapes are %(type2)%?
#
#                                                                  Problem3  \
# Problem Name
# %(startStateNodeName)%                                           example3
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/03.png
# %(question1)%               (1) What percent of the shapes are %(type1)%?
# %(question2)%               (2) What percent of the shapes are %(type2)%?
#
#                                                                  Problem4  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/04.png
# %(question1)%               (1) What percent of the shapes are %(type1)%?
# %(question2)%               (2) What percent of the shapes are %(type2)%?
#
#                                                                  Problem5  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/05.png
# %(question1)%               (1) What percent of the shapes are %(type1)%?
# %(question2)%               (2) What percent of the shapes are %(type2)%?
#
#                                                                  Problem6  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/06.png
# %(question1)%               (1) What percent of the shapes are %(type1)%?
# %(question2)%               (2) What percent of the shapes are %(type2)%?
#
#                                                                  Problem7  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/07.png
# %(question1)%               (1) What percent of the shapes are %(type1)%?
# %(question2)%               (2) What percent of the shapes are %(type2)%?
#
#                                                                  Problem8
# Problem Name
# %(startStateNodeName)%
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/08.png
# %(question1)%               (1) What percent of the shapes are %(type1)%?
# %(question2)%               (2) What percent of the shapes are %(type2)%?

# %%
# replace variable with value in the latest mass production table
# iterate column and row in table_new
for column in range(table_new.shape[1]):
    for row in range(table_new.shape[0]):
        content_new = str(table_new.iloc[row, column])
        start_pattern = "%\("
        # count the number of the replacement in one variable(content_new)
        count = [match.start() for match in re.finditer(start_pattern, str(content_new))]
        for i in range(len(count)):
            # find the variable
            start_pattern = "%\("
            start_index = [match.start() for match in re.finditer(start_pattern, str(content_new))]
            end_pattern = "\)%"
            end_index = [match.start() for match in re.finditer(end_pattern, str(content_new))]
            # no need for replacement
            if start_index == []:
                continue
            else:
                variable = content_new[start_index[0]: end_index[0]+2]
                # find the corresponding column name, and then find the value
                column_name = table_new.columns[column]
                try:
                    value = table_new.loc[variable, column_name] 
                    # print(variable, value)
                    content_new = content_new.replace(variable, value)
                    table_new.iloc[row, column] = content_new
                except:
                    print(variable + " doesn't exist")
table_new.head()
# Out:
# %(imgNum)% doesn't exist
# %(imgNum)% doesn't exist
# %(imgNum)% doesn't exist
# %(imgNum)% doesn't exist
# %(imgNum)% doesn't exist
# %(imgNum)% doesn't exist
# %(imgNum)% doesn't exist
# %(imgNum)% doesn't exist
#                                                                  Problem1  \
# Problem Name
# %(startStateNodeName)%                                           example1
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/01.png
# %(question1)%                 (1) What percent of the shapes are squares?
# %(question2)%                  (2) What percent of the shapes are purple?
#
#                                                                  Problem2  \
# Problem Name
# %(startStateNodeName)%                                           example2
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/02.png
# %(question1)%                   (1) What percent of the shapes are green?
# %(question2)%                  (2) What percent of the shapes are yellow?
#
#                                                                  Problem3  \
# Problem Name
# %(startStateNodeName)%                                           example3
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/03.png
# %(question1)%                  (1) What percent of the shapes are yellow?
# %(question2)%                 (2) What percent of the shapes are circles?
#
#                                                                  Problem4  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/04.png
# %(question1)%                 (1) What percent of the shapes are circles?
# %(question2)%                  (2) What percent of the shapes are yellow?
#
#                                                                  Problem5  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/05.png
# %(question1)%             (1) What percent of the shapes are red or blue?
# %(question2)%              (2) What percent of the shapes are not purple?
#
#                                                                  Problem6  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/06.png
# %(question1)%              (1) What percent of the shapes are not yellow?
# %(question2)%             (2) What percent of the shapes are red circles?
#
#                                                                  Problem7  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/07.png
# %(question1)%                 (1) What percent of the shapes are squares?
# %(question2)%                  (2) What percent of the shapes are purple?
#
#                                                                  Problem8
# Problem Name
# %(startStateNodeName)%
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/08.png
# %(question1)%            (1) What percent of the shapes are blue circles?
# %(question2)%           (2) What percent of the shapes are yellow or g...

# %%
# read the Greg's mass production table
path_old = './Greg_table_folder/6.05 - Sheet1.csv'
# path_old = './Greg_table_folder/7.17 - Sheet1.csv'
table_old = pd.read_csv(path_old, header = None)
# table_old.head()
# skip some rows, because they are translation for HTML elements
header_index = table_old.index[table_old[0] == 'Problem Name'].to_list()
# header_index
# reload the csv
table_old = pd.read_csv(path_old, header = header_index)
table_old.columns
# Out:
# Index(['Problem Name', 'Problem1', 'ProblemESP1', 'Problem Name.1', 'Problem2',
#        'ProblemESP2', 'Problem Name.2', 'Problem3', 'ProblemESP3',
#        'Problem Name.3', 'Problem4', 'ProblemESP4', 'Problem Name.4',
#        'Problem5', 'ProblemESP5', 'Problem Name.5', 'Problem6', 'ProblemESP6',
#        'Problem Name.6', 'Problem7', 'ProblemESP7', 'Problem Name.7',
#        'Problem8', 'ProblemESP8'],
#       dtype='object')

# %%
# table_translated = pd.DataFrame(columns=table_old.columns, index=range(table_new.shape[0]))
# Create a new table, with the column from the Greg's mass production table and the index from the latest mass production table
table_translated = pd.DataFrame(columns=table_old.columns, index=table_new.index)
table_translated
# Out:
#                                 Problem Name Problem1 ProblemESP1  \
# Problem Name
# %(startStateNodeName)%                   NaN      NaN         NaN
# %(statement)%                            NaN      NaN         NaN
# %(graphic)%                              NaN      NaN         NaN
# %(question1)%                            NaN      NaN         NaN
# %(question2)%                            NaN      NaN         NaN
# ...                                      ...      ...         ...
# %(Input_74_percent4)%                    NaN      NaN         NaN
# %(Input_78_simplifytar1tot110)%          NaN      NaN         NaN
# %(Input_82_simplifytar2tot210)%          NaN      NaN         NaN
# %(Input_86_simplifytar3tot310)%          NaN      NaN         NaN
# %(Input_90_simplifytar4tot410)%          NaN      NaN         NaN
#
#                                 Problem Name.1 Problem2 ProblemESP2  \
# Problem Name
# %(startStateNodeName)%                     NaN      NaN         NaN
# %(statement)%                              NaN      NaN         NaN
# %(graphic)%                                NaN      NaN         NaN
# %(question1)%                              NaN      NaN         NaN
# %(question2)%                              NaN      NaN         NaN
# ...                                        ...      ...         ...
# %(Input_74_percent4)%                      NaN      NaN         NaN
# %(Input_78_simplifytar1tot110)%            NaN      NaN         NaN
# %(Input_82_simplifytar2tot210)%            NaN      NaN         NaN
# %(Input_86_simplifytar3tot310)%            NaN      NaN         NaN
# %(Input_90_simplifytar4tot410)%            NaN      NaN         NaN
#
#                                 Problem Name.2 Problem3 ProblemESP3  \
# Problem Name
# %(startStateNodeName)%                     NaN      NaN         NaN
# %(statement)%                              NaN      NaN         NaN
# %(graphic)%                                NaN      NaN         NaN
# %(question1)%                              NaN      NaN         NaN
# %(question2)%                              NaN      NaN         NaN
# ...                                        ...      ...         ...
# %(Input_74_percent4)%                      NaN      NaN         NaN
# %(Input_78_simplifytar1tot110)%            NaN      NaN         NaN
# %(Input_82_simplifytar2tot210)%            NaN      NaN         NaN
# %(Input_86_simplifytar3tot310)%            NaN      NaN         NaN
# %(Input_90_simplifytar4tot410)%            NaN      NaN         NaN
#
#                                 Problem Name.3  ... ProblemESP5  \
# Problem Name                                    ...
# %(startStateNodeName)%                     NaN  ...         NaN
# %(statement)%                              NaN  ...         NaN
# %(graphic)%                                NaN  ...         NaN
# %(question1)%                              NaN  ...         NaN
# %(question2)%                              NaN  ...         NaN
# ...                                        ...  ...         ...
# %(Input_74_percent4)%                      NaN  ...         NaN
# %(Input_78_simplifytar1tot110)%            NaN  ...         NaN
# %(Input_82_simplifytar2tot210)%            NaN  ...         NaN
# %(Input_86_simplifytar3tot310)%            NaN  ...         NaN
# %(Input_90_simplifytar4tot410)%            NaN  ...         NaN
#
#                                 Problem Name.5 Problem6 ProblemESP6  \
# Problem Name
# %(startStateNodeName)%                     NaN      NaN         NaN
# %(statement)%                              NaN      NaN         NaN
# %(graphic)%                                NaN      NaN         NaN
# %(question1)%                              NaN      NaN         NaN
# %(question2)%                              NaN      NaN         NaN
# ...                                        ...      ...         ...
# %(Input_74_percent4)%                      NaN      NaN         NaN
# %(Input_78_simplifytar1tot110)%            NaN      NaN         NaN
# %(Input_82_simplifytar2tot210)%            NaN      NaN         NaN
# %(Input_86_simplifytar3tot310)%            NaN      NaN         NaN
# %(Input_90_simplifytar4tot410)%            NaN      NaN         NaN
#
#                                 Problem Name.6 Problem7 ProblemESP7  \
# Problem Name
# %(startStateNodeName)%                     NaN      NaN         NaN
# %(statement)%                              NaN      NaN         NaN
# %(graphic)%                                NaN      NaN         NaN
# %(question1)%                              NaN      NaN         NaN
# %(question2)%                              NaN      NaN         NaN
# ...                                        ...      ...         ...
# %(Input_74_percent4)%                      NaN      NaN         NaN
# %(Input_78_simplifytar1tot110)%            NaN      NaN         NaN
# %(Input_82_simplifytar2tot210)%            NaN      NaN         NaN
# %(Input_86_simplifytar3tot310)%            NaN      NaN         NaN
# %(Input_90_simplifytar4tot410)%            NaN      NaN         NaN
#
#                                 Problem Name.7 Problem8 ProblemESP8
# Problem Name
# %(startStateNodeName)%                     NaN      NaN         NaN
# %(statement)%                              NaN      NaN         NaN
# %(graphic)%                                NaN      NaN         NaN
# %(question1)%                              NaN      NaN         NaN
# %(question2)%                              NaN      NaN         NaN
# ...                                        ...      ...         ...
# %(Input_74_percent4)%                      NaN      NaN         NaN
# %(Input_78_simplifytar1tot110)%            NaN      NaN         NaN
# %(Input_82_simplifytar2tot210)%            NaN      NaN         NaN
# %(Input_86_simplifytar3tot310)%            NaN      NaN         NaN
# %(Input_90_simplifytar4tot410)%            NaN      NaN         NaN
#
# [187 rows x 24 columns]

# %%
google_dict = {}

# %%
# find the translation of the latest mass production table from the Greg's mass production table 
for column in range(table_new.shape[1]):
    for row in range(table_new.shape[0]):
        content_new = str(table_new.iloc[row, column])
        column_name = table_new.columns[column]
        table_translated[column_name].iloc[row] = content_new
        column_num = table_translated.columns.get_loc(column_name)
        # if re is used to match, the "(" should be replaced by "\("
        # content_new = content_new.replace("(", "\(")
        # content_new = content_new.replace(")", "\)")
        # no translation
        if table_old[table_old[column_name] == str(content_new)].empty:
            if content_new in google_dict:
                content_translated = google_dict[content_new]
            else:
                try:
                    translation = tss.google(content_new, from_language='en', to_language=TARGET_LANG)
                except:
                    translation = 'error'
                content_translated = '[google]' + translation
                google_dict[content_new] = content_translated
            # content_translated = '[google]'
        # find translation
        else:
            content_translated = table_old[table_old[column_name] == str(content_new)].iloc[0,column_num+1]
        # print(content_new, content_translated)
        # content_translated = str(content_translated).replace("['" ,"").replace("']" ,"")
        # print(content_translated)
        table_translated.iloc[row, column_num+1] = content_translated
        # # content_translated
# table_translated

# %%
table_translated.head()
# Out:
#                        Problem Name  \
# Problem Name
# %(startStateNodeName)%          NaN
# %(statement)%                   NaN
# %(graphic)%                     NaN
# %(question1)%                   NaN
# %(question2)%                   NaN
#
#                                                                  Problem1  \
# Problem Name
# %(startStateNodeName)%                                           example1
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/01.png
# %(question1)%                 (1) What percent of the shapes are squares?
# %(question2)%                  (2) What percent of the shapes are purple?
#
#                                                               ProblemESP1  \
# Problem Name
# %(startStateNodeName)%                                  [google]Ejemplo 1
# %(statement)%           Usando el conjunto de formas en la imagen, res...
# %(graphic)%                                                 Assets/01.png
# %(question1)%            (1) ¿Qué porcentaje de las formas son cuadrados?
# %(question2)%              (2) ¿Qué porcentaje de las formas son moradas?
#
#                        Problem Name.1  \
# Problem Name
# %(startStateNodeName)%            NaN
# %(statement)%                     NaN
# %(graphic)%                       NaN
# %(question1)%                     NaN
# %(question2)%                     NaN
#
#                                                                  Problem2  \
# Problem Name
# %(startStateNodeName)%                                           example2
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/02.png
# %(question1)%                   (1) What percent of the shapes are green?
# %(question2)%                  (2) What percent of the shapes are yellow?
#
#                                                               ProblemESP2  \
# Problem Name
# %(startStateNodeName)%                                   [google]ejemplo2
# %(statement)%           Usando el conjunto de formas en la imagen, res...
# %(graphic)%                                                 Assets/02.png
# %(question1)%               (1) ¿Qué porcentaje de las formas son verdes?
# %(question2)%            (2) ¿Qué porcentaje de las formas son amarillas?
#
#                        Problem Name.2  \
# Problem Name
# %(startStateNodeName)%            NaN
# %(statement)%                     NaN
# %(graphic)%                       NaN
# %(question1)%                     NaN
# %(question2)%                     NaN
#
#                                                                  Problem3  \
# Problem Name
# %(startStateNodeName)%                                           example3
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/03.png
# %(question1)%                  (1) What percent of the shapes are yellow?
# %(question2)%                 (2) What percent of the shapes are circles?
#
#                                                               ProblemESP3  \
# Problem Name
# %(startStateNodeName)%                                   [google]ejemplo3
# %(statement)%           Usando el conjunto de formas en la imagen, res...
# %(graphic)%                                              Activos / 03.png
# %(question1)%            (1) ¿Qué porcentaje de las formas son amarillas?
# %(question2)%             (2) ¿Qué porcentaje de las formas son círculos?
#
#                        Problem Name.3  ...  \
# Problem Name                           ...
# %(startStateNodeName)%            NaN  ...
# %(statement)%                     NaN  ...
# %(graphic)%                       NaN  ...
# %(question1)%                     NaN  ...
# %(question2)%                     NaN  ...
#
#                                                               ProblemESP5  \
# Problem Name
# %(startStateNodeName)%                                      [google]error
# %(statement)%           Usando el conjunto de formas en la imagen, res...
# %(graphic)%                                                 Assets/05.png
# %(question1)%           (1) ¿Qué porcentaje de las formas son rojas o ...
# %(question2)%           (2) ¿Qué porcentaje de las formas no son moradas?
#
#                        Problem Name.5  \
# Problem Name
# %(startStateNodeName)%            NaN
# %(statement)%                     NaN
# %(graphic)%                       NaN
# %(question1)%                     NaN
# %(question2)%                     NaN
#
#                                                                  Problem6  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/06.png
# %(question1)%              (1) What percent of the shapes are not yellow?
# %(question2)%             (2) What percent of the shapes are red circles?
#
#                                                               ProblemESP6  \
# Problem Name
# %(startStateNodeName)%                                      [google]error
# %(statement)%           Usando el conjunto de formas en la imagen, res...
# %(graphic)%                                              Activos / 06.png
# %(question1)%           (1) ¿Qué porcentaje de las formas no son amari...
# %(question2)%           (2) ¿Qué porcentaje de las formas son círculos...
#
#                        Problem Name.6  \
# Problem Name
# %(startStateNodeName)%            NaN
# %(statement)%                     NaN
# %(graphic)%                       NaN
# %(question1)%                     NaN
# %(question2)%                     NaN
#
#                                                                  Problem7  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/07.png
# %(question1)%                 (1) What percent of the shapes are squares?
# %(question2)%                  (2) What percent of the shapes are purple?
#
#                                                               ProblemESP7  \
# Problem Name
# %(startStateNodeName)%                                      [google]error
# %(statement)%           Usando el conjunto de formas en la imagen, res...
# %(graphic)%                                                 Assets/07.png
# %(question1)%            (1) ¿Qué porcentaje de las formas son cuadrados?
# %(question2)%              (2) ¿Qué porcentaje de las formas son moradas?
#
#                        Problem Name.7  \
# Problem Name
# %(startStateNodeName)%            NaN
# %(statement)%                     NaN
# %(graphic)%                       NaN
# %(question1)%                     NaN
# %(question2)%                     NaN
#
#                                                                  Problem8  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%           Using the set of shapes in the picture, answer...
# %(graphic)%                                                 Assets/08.png
# %(question1)%            (1) What percent of the shapes are blue circles?
# %(question2)%           (2) What percent of the shapes are yellow or g...
#
#                                                               ProblemESP8
# Problem Name
# %(startStateNodeName)%                                      [google]error
# %(statement)%           Usando el conjunto de formas en la imagen, res...
# %(graphic)%                                                 Assets/08.png
# %(question1)%           (1) ¿Qué porcentaje de las formas son círculos...
# %(question2)%           (2) ¿Qué porcentaje de las formas son amarilla...
#
# [5 rows x 24 columns]

# %%
# drop NaN columns
table_translated_drop = table_translated.dropna(axis = 1, how = "any")
table_translated_drop
# Out:
#                                                                           Problem1  \
# Problem Name
# %(startStateNodeName)%                                                    example1
# %(statement)%                    Using the set of shapes in the picture, answer...
# %(graphic)%                                                          Assets/01.png
# %(question1)%                          (1) What percent of the shapes are squares?
# %(question2)%                           (2) What percent of the shapes are purple?
# ...                                                                            ...
# %(Input_74_percent4)%                                                           5%
# %(Input_78_simplifytar1tot110)%                               simplify(100/100*10)
# %(Input_82_simplifytar2tot210)%                                simplify(20/100*10)
# %(Input_86_simplifytar3tot310)%                                simplify(60/100*10)
# %(Input_90_simplifytar4tot410)%                                 simplify(5/100*10)
#
#                                                                        ProblemESP1  \
# Problem Name
# %(startStateNodeName)%                                           [google]Ejemplo 1
# %(statement)%                    Usando el conjunto de formas en la imagen, res...
# %(graphic)%                                                          Assets/01.png
# %(question1)%                     (1) ¿Qué porcentaje de las formas son cuadrados?
# %(question2)%                       (2) ¿Qué porcentaje de las formas son moradas?
# ...                                                                            ...
# %(Input_74_percent4)%                                                           5%
# %(Input_78_simplifytar1tot110)%                         simplificar (100/100 * 10)
# %(Input_82_simplifytar2tot210)%                          simplificar (20/100 * 10)
# %(Input_86_simplifytar3tot310)%                          simplificar (60/100 * 10)
# %(Input_90_simplifytar4tot410)%                           simplificar (5/100 * 10)
#
#                                                                           Problem2  \
# Problem Name
# %(startStateNodeName)%                                                    example2
# %(statement)%                    Using the set of shapes in the picture, answer...
# %(graphic)%                                                          Assets/02.png
# %(question1)%                            (1) What percent of the shapes are green?
# %(question2)%                           (2) What percent of the shapes are yellow?
# ...                                                                            ...
# %(Input_74_percent4)%                                                          75%
# %(Input_78_simplifytar1tot110)%                                  simplify(1/20*10)
# %(Input_82_simplifytar2tot210)%                                  simplify(8/20*10)
# %(Input_86_simplifytar3tot310)%                                  simplify(5/20*10)
# %(Input_90_simplifytar4tot410)%                                 simplify(15/20*10)
#
#                                                                        ProblemESP2  \
# Problem Name
# %(startStateNodeName)%                                            [google]ejemplo2
# %(statement)%                    Usando el conjunto de formas en la imagen, res...
# %(graphic)%                                                          Assets/02.png
# %(question1)%                        (1) ¿Qué porcentaje de las formas son verdes?
# %(question2)%                     (2) ¿Qué porcentaje de las formas son amarillas?
# ...                                                                            ...
# %(Input_74_percent4)%                                                          75%
# %(Input_78_simplifytar1tot110)%                           vsimplificar (1/20 * 10)
# %(Input_82_simplifytar2tot210)%                            simplificar (8/20 * 10)
# %(Input_86_simplifytar3tot310)%                            simplificar (5/20 * 10)
# %(Input_90_simplifytar4tot410)%                           simplificar (15/20 * 10)
#
#                                                                           Problem3  \
# Problem Name
# %(startStateNodeName)%                                                    example3
# %(statement)%                    Using the set of shapes in the picture, answer...
# %(graphic)%                                                          Assets/03.png
# %(question1)%                           (1) What percent of the shapes are yellow?
# %(question2)%                          (2) What percent of the shapes are circles?
# ...                                                                            ...
# %(Input_74_percent4)%                                                          70%
# %(Input_78_simplifytar1tot110)%                                  simplify(5/50*10)
# %(Input_82_simplifytar2tot210)%                                 simplify(25/50*10)
# %(Input_86_simplifytar3tot310)%                                 simplify(45/50*10)
# %(Input_90_simplifytar4tot410)%                                 simplify(35/50*10)
#
#                                                                        ProblemESP3  \
# Problem Name
# %(startStateNodeName)%                                            [google]ejemplo3
# %(statement)%                    Usando el conjunto de formas en la imagen, res...
# %(graphic)%                                                       Activos / 03.png
# %(question1)%                     (1) ¿Qué porcentaje de las formas son amarillas?
# %(question2)%                      (2) ¿Qué porcentaje de las formas son círculos?
# ...                                                                            ...
# %(Input_74_percent4)%                                                          70%
# %(Input_78_simplifytar1tot110)%                            simplificar (5/50 * 10)
# %(Input_82_simplifytar2tot210)%                           simplificar (25/50 * 10)
# %(Input_86_simplifytar3tot310)%                           simplificar (45/50 * 10)
# %(Input_90_simplifytar4tot410)%                           simplificar (35/50 * 10)
#
#                                                                           Problem4  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%                    Using the set of shapes in the picture, answer...
# %(graphic)%                                                          Assets/04.png
# %(question1)%                          (1) What percent of the shapes are circles?
# %(question2)%                           (2) What percent of the shapes are yellow?
# ...                                                                            ...
# %(Input_74_percent4)%                                                          60%
# %(Input_78_simplifytar1tot110)%                                 simplify(10/25*10)
# %(Input_82_simplifytar2tot210)%                                  simplify(5/25*10)
# %(Input_86_simplifytar3tot310)%                                 simplify(20/25*10)
# %(Input_90_simplifytar4tot410)%                                 simplify(15/25*10)
#
#                                                                        ProblemESP4  \
# Problem Name
# %(startStateNodeName)%                                               [google]error
# %(statement)%                    Usando el conjunto de formas en la imagen, res...
# %(graphic)%                                                          Assets/04.png
# %(question1)%                      (1) ¿Qué porcentaje de las formas son círculos?
# %(question2)%                     (2) ¿Qué porcentaje de las formas son amarillas?
# ...                                                                            ...
# %(Input_74_percent4)%                                                          60%
# %(Input_78_simplifytar1tot110)%                           simplificar (10/25 * 10)
# %(Input_82_simplifytar2tot210)%                            simplificar (5/25 * 10)
# %(Input_86_simplifytar3tot310)%                           simplificar (20/25 * 10)
# %(Input_90_simplifytar4tot410)%                           simplificar (15/25 * 10)
#
#                                                                           Problem5  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%                    Using the set of shapes in the picture, answer...
# %(graphic)%                                                          Assets/05.png
# %(question1)%                      (1) What percent of the shapes are red or blue?
# %(question2)%                       (2) What percent of the shapes are not purple?
# ...                                                                            ...
# %(Input_74_percent4)%                                                          10%
# %(Input_78_simplifytar1tot110)%                                  simplify(7/10*10)
# %(Input_82_simplifytar2tot210)%                                  simplify(9/10*10)
# %(Input_86_simplifytar3tot310)%                                  simplify(4/10*10)
# %(Input_90_simplifytar4tot410)%                                  simplify(1/10*10)
#
#                                                                        ProblemESP5  \
# Problem Name
# %(startStateNodeName)%                                               [google]error
# %(statement)%                    Usando el conjunto de formas en la imagen, res...
# %(graphic)%                                                          Assets/05.png
# %(question1)%                    (1) ¿Qué porcentaje de las formas son rojas o ...
# %(question2)%                    (2) ¿Qué porcentaje de las formas no son moradas?
# ...                                                                            ...
# %(Input_74_percent4)%                                                          10%
# %(Input_78_simplifytar1tot110)%                            simplificar (7/10 * 10)
# %(Input_82_simplifytar2tot210)%                            simplificar (9/10 * 10)
# %(Input_86_simplifytar3tot310)%                            simplificar (4/10 * 10)
# %(Input_90_simplifytar4tot410)%                            simplificar (1/10 * 10)
#
#                                                                           Problem6  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%                    Using the set of shapes in the picture, answer...
# %(graphic)%                                                          Assets/06.png
# %(question1)%                       (1) What percent of the shapes are not yellow?
# %(question2)%                      (2) What percent of the shapes are red circles?
# ...                                                                            ...
# %(Input_74_percent4)%                                                          65%
# %(Input_78_simplifytar1tot110)%                                 simplify(38/40*10)
# %(Input_82_simplifytar2tot210)%                                 simplify(14/40*10)
# %(Input_86_simplifytar3tot310)%                                  simplify(9/40*10)
# %(Input_90_simplifytar4tot410)%                                 simplify(26/40*10)
#
#                                                                           Problem7  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%                    Using the set of shapes in the picture, answer...
# %(graphic)%                                                          Assets/07.png
# %(question1)%                          (1) What percent of the shapes are squares?
# %(question2)%                           (2) What percent of the shapes are purple?
# ...                                                                            ...
# %(Input_74_percent4)%                                                          60%
# %(Input_78_simplifytar1tot110)%                                   simplify(2/5*10)
# %(Input_82_simplifytar2tot210)%                                   simplify(1/5*10)
# %(Input_86_simplifytar3tot310)%                                   simplify(4/5*10)
# %(Input_90_simplifytar4tot410)%                                   simplify(3/5*10)
#
#                                                                        ProblemESP7  \
# Problem Name
# %(startStateNodeName)%                                               [google]error
# %(statement)%                    Usando el conjunto de formas en la imagen, res...
# %(graphic)%                                                          Assets/07.png
# %(question1)%                     (1) ¿Qué porcentaje de las formas son cuadrados?
# %(question2)%                       (2) ¿Qué porcentaje de las formas son moradas?
# ...                                                                            ...
# %(Input_74_percent4)%                                                          60%
# %(Input_78_simplifytar1tot110)%                             simplificar (2/5 * 10)
# %(Input_82_simplifytar2tot210)%                             simplificar (1/5 * 10)
# %(Input_86_simplifytar3tot310)%                             simplificar (4/5 * 10)
# %(Input_90_simplifytar4tot410)%                             simplificar (3/5 * 10)
#
#                                                                           Problem8  \
# Problem Name
# %(startStateNodeName)%
# %(statement)%                    Using the set of shapes in the picture, answer...
# %(graphic)%                                                          Assets/08.png
# %(question1)%                     (1) What percent of the shapes are blue circles?
# %(question2)%                    (2) What percent of the shapes are yellow or g...
# ...                                                                            ...
# %(Input_74_percent4)%                                                          60%
# %(Input_78_simplifytar1tot110)%                                  simplify(3/15*10)
# %(Input_82_simplifytar2tot210)%                                  simplify(6/15*10)
# %(Input_86_simplifytar3tot310)%                                 simplify(12/15*10)
# %(Input_90_simplifytar4tot410)%                                  simplify(9/15*10)
#
#                                                                        ProblemESP8
# Problem Name
# %(startStateNodeName)%                                               [google]error
# %(statement)%                    Usando el conjunto de formas en la imagen, res...
# %(graphic)%                                                          Assets/08.png
# %(question1)%                    (1) ¿Qué porcentaje de las formas son círculos...
# %(question2)%                    (2) ¿Qué porcentaje de las formas son amarilla...
# ...                                                                            ...
# %(Input_74_percent4)%                                                          60%
# %(Input_78_simplifytar1tot110)%                            simplificar (3/15 * 10)
# %(Input_82_simplifytar2tot210)%                            simplificar (6/15 * 10)
# %(Input_86_simplifytar3tot310)%                           simplificar (12/15 * 10)
# %(Input_90_simplifytar4tot410)%                                  simplify(9/15*10)
#
# [187 rows x 15 columns]

# %%
# export the csv
table_translated_drop.to_csv('./Output_translated_folder/6.5_translated.txt', encoding="utf-8", sep="\t")
# table_translated_drop.to_csv('./Output_translated_folder/7.17_translated.txt', encoding="utf-8", sep="\t")
